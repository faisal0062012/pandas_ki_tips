# %% [markdown]
# # Seaborn and Plotting

# %%
# import liberaries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # important things for plottings according to grammar of graphics
# 1. data (df)
# 2. types of plot
# 3. x axis
# 4. y axis
# 5. grouping (hue/color) based on cat variable
# 6. size of plot
# 7. color pallets
# 8. style of plot
# 9. How do you interpret

# %%
# Data
df = sns.load_dataset('titanic')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# scatter plot
# plot size or figure size
plt.figure(figsize=(6,6))
sns.scatterplot(data = df, x= 'age', y= 'fare', hue= 'sex')
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
# scatter plot
# plot size or figure size
plt.figure(figsize=(6,6))
sns.scatterplot(data = df, x= 'age', y= 'fare', hue= 'sex')
# change the scatter point colors
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
plt.figure(figsize=(6,6))
sns.scatterplot(data=df, x='age', y='fare', hue='sex', palette=['#FF69B4', '#32CD32'])
# Out:
# <Axes: xlabel='age', ylabel='fare'>

# %%
plt.figure(figsize=(6,6))
# change the scatter point colors
palet = {'male':'blue', 'female': 'green'}
sns.scatterplot(data = df, x= 'age', y= 'fare', hue= 'sex', palette= palet)
# labels
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('scatter plot of age vs fare')

# saving a plot 300dpi, 600dpi, 1500dpi png
plt.savefig('./output/scatter_plot.png', dpi= 300)

# saving a plot in vector file such as svg
plt.savefig('./output/scatter_plot.svg')

# %%
# style of plot

sns.set_theme(style='darkgrid', font_scale=1.5, font= 'Times New Roman')

# change the scatter point colors
palet = {'male':'blue', 'female': 'green'}
sns.scatterplot(data = df, x= 'age', y= 'fare',size= 'fare', hue= 'sex', palette= palet)
# labels
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('scatter plot of age vs fare')
# Out:
# Text(0.5, 1.0, 'scatter plot of age vs fare')

# %% [markdown]
# Interpretation
# 1. we have age of passenger at x-axis and fare at y-axis
# 2. the scatter plot shows the relationship between age and fare of titanic passenger
# 3. we further grouped the passengers by their gender such as male (blue points) and female (green points)
# 4. two male passenger gave the highest fare in titanic and they might be travelling in first class
# 5. the oldest person at titanic is also a male, having 80 years of age as shown in scatter plot

# %% [markdown]
# Plotting with Seaborn in Python | Data Visualization (Part-4)
# 25:40 /44:44

# %% [markdown]
# # Box Plot

# %%
df['class'].unique()
# Out:
# ['Third', 'First', 'Second']
# Categories (3, object): ['First', 'Second', 'Third']

# %%
# style of plot

sns.set_theme(style='darkgrid', font_scale=1.0, font= 'Times New Roman')

# change the scatter point colors
palet = {'First':'blue', 'Second': 'green', 'Third':'red'}
sns.boxplot(data = df, x= 'sex', y= 'age', hue= 'class', palette= palet)
# labels
plt.xlabel('sex')
plt.ylabel('age')
plt.title('Box plot of sex vs age')

# change the legend position
plt.legend(loc='upper right', title= 'Class Name')

# %% [markdown]
# # Boxen Plot

# %%
# style of plot

sns.set_theme(style='darkgrid', font_scale=1.0, font= 'Times New Roman')

# change the scatter point colors
palet = {'First':'blue', 'Second': 'green', 'Third':'red'}
sns.boxenplot(data = df, x= 'sex', y= 'age', hue= 'class', palette= palet)
# labels
plt.xlabel('Gender')
plt.ylabel('age')
plt.title('Boxen plot of Gender vs age')

# change the legend position
plt.legend(loc='upper right', title= 'Class Name')

# change the x-ticks name
plt.xticks(ticks=[0,1], labels=["Male","Female"], rotation= 45)
# Out:
# ([<matplotlib.axis.XTick at 0x16f98c93d40>,
# ...
#  [Text(0, 0, 'Male'), Text(1, 0, 'Female')])

# %%
# make scatter plot with plotly
import plotly.express as px

# %%
fig= px.scatter(df, x= 'age', y= 'fare', color= 'sex')
fig.show()

# %% [markdown]
# # Bar Plot

# %%
# style of plot

sns.set_theme(style='darkgrid', font_scale=1.0, font= 'Times New Roman')

# change the scatter point colors
palet = {'First':'blue', 'Second': 'green', 'Third':'red'}
sns.barplot(data = df, x= 'sex', y= 'age', hue= 'class', palette= palet, capsize=0.5)
# labels
plt.xlabel('Gender')
plt.ylabel('age')
plt.title('Bar plot of Gender vs age')

# change the legend position
plt.legend(loc='upper right', title= 'Class Name')

# change the x-ticks name
plt.xticks(ticks=[0,1], labels=["Male","Female"], rotation= 45)
# Out:
# ([<matplotlib.axis.XTick at 0x16f9c4b86b0>,
# ...
#  [Text(0, 0, 'Male'), Text(1, 0, 'Female')])

# %% [markdown]
# # Violin plot

# %%
# style of plot

sns.set_theme(style='darkgrid', font_scale=1.0, font= 'Times New Roman')

# change the scatter point colors
palet = {'First':'blue', 'Second': 'green', 'Third':'red'}
sns.violinplot(data = df, x= 'sex', y= 'age', hue= 'class', palette= palet)
# labels
plt.xlabel('Gender')
plt.ylabel('age')
plt.title('Bar plot of Gender vs age')

# change the legend position
plt.legend(loc='upper right', title= 'Class Name')

# change the x-ticks name
plt.xticks(ticks=[0,1], labels=["Male","Female"], rotation= 45)
# Out:
# ([<matplotlib.axis.XTick at 0x16f9e134320>,
# ...
#  [Text(0, 0, 'Male'), Text(1, 0, 'Female')])
